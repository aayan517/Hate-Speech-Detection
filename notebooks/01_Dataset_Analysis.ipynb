# %% [markdown]
# # AI-Assisted Hate Speech Detection
#
# ## Dataset Analysis of the Davidson Hate Speech and Offensive Language Dataset
#
# ### Objective
#
# The objective of this notebook is to explore and understand the Davidson Hate Speech and Offensive Language Dataset before applying any preprocessing or machine learning models.
#
# This analysis includes examining the dataset structure, identifying missing and duplicate values, understanding the class distribution, and drawing initial observations that will guide the implementation of Machine Learning, Deep Learning, and Transformer-based models in later stages of the project.

# %%
# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt

# Statistical Visualization
import seaborn as sns

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# Display Settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Data Manipulation
# ----> 2 import pandas as pd
#       3 import numpy as np
#       5 # Data Visualization
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv("../data/raw/labeled_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("../data/raw/labeled_data.csv")
#
# NameError: name 'pd' is not defined

# %%
print("Hello, Ayan!")
# Out:
# Hello, Ayan!

# %%
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset.head()
#
# NameError: name 'dataset' is not defined

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Ayanm\AppData\Local\Programs\Python\Python312\python.exe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
df = pd.read_csv("../data/raw/labeled_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_csv("../data/raw/labeled_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
df.shape
# Out:
# (24783, 7)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'count', 'hate_speech', 'offensive_language', 'neither',
#        'class', 'tweet'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
#  2   hate_speech         24783 non-null  int64
#  3   offensive_language  24783 non-null  int64
#  4   neither             24783 non-null  int64
#  5   class               24783 non-null  int64
#  6   tweet               24783 non-null  str
# dtypes: int64(6), str(1)
# memory usage: 1.3 MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# count                 0
# hate_speech           0
# offensive_language    0
# neither               0
# class                 0
# tweet                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["class"].value_counts()
# Out:
# class
# 1    19190
# 2     4163
# 0     1430
# Name: count, dtype: int64

# %%
df["class"].value_counts().plot(kind="bar")
plt.title("Distribution of Classes")
plt.xlabel("Class")
plt.ylabel("Number of Tweets")
plt.show()
